# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('freq.xlsx')
df
# Out:
#          Multiple congress attemps  lingering chr at poles   bad met  \
# DMSO                          0.25                0.250000  0.500000
# Prodrug                       0.00                0.500000  0.000000
# C4                            0.00                0.500000  0.250000
# B4                            0.00                0.833333  0.166667
#
#          not all chr congress  total align defect  lagging chr  \
# DMSO                     0.00                1.00     0.000000
# Prodrug                  0.25                0.75     0.000000
# C4                       0.00                0.75     0.500000
# B4                       0.50                1.50     0.166667
#
#          straggling chr in ana  total ana defects
# DMSO                  0.000000               0.00
# Prodrug               0.750000               0.75
# C4                    0.000000               0.50
# B4                    0.333333               0.50

# %%
# This is a figure to show the freq of different defective chr behavior in control/ exp PtK2 cells.
fig = plt.figure(figsize=(10, 4))
plt.title('Frequency Analysis')
sns.heatmap(df, cmap ='coolwarm')

# %%
# This is a figure to show the freq of different defective chr behavior in control/ exp PtK2 cells with annotations.
fig = plt.figure(figsize=(10, 4))
plt.title('Frequency Analysis')
sns.heatmap(df, cmap ='coolwarm', annot= df)

# %%
# Let's try the clustering algo to see cells behavior similiarity.
sns.clustermap(df, cmap ='coolwarm', col_cluster=False, figsize=(10, 5))

# %%
df2 = pd.read_excel('Workbook1.xlsx', index_col='Treatment')
df2
# Out:
#            Normal  Multipolar  Lagging Chr division  Cell Death  \
# Treatment
# DMSO         0.98        0.00                  0.00        0.00
# Prodrug      0.62        0.04                  0.02        0.02
# C4           0.68        0.04                  0.06        0.00
# B4           0.88        0.06                  0.02        0.02
#
#            Failed Division
# Treatment
# DMSO                  0.02
# Prodrug               0.30
# C4                    0.22
# B4                    0.02

# %%
# This is a figure to show the freq of different defective chr behavior in control/ exp HeLa cells in HTM.
fig = plt.figure(figsize=(10, 4))
plt.title('Frequency Analysis')
cmap = sns.light_palette("#2ecc71", as_cmap=True, reverse=True)
sns.heatmap(df2, cmap = cmap,)

# %%
cmap = sns.light_palette("#2ecc71", as_cmap=True, reverse=True)
sns.clustermap(df2, cmap = cmap, col_cluster=False, figsize=(10, 5))
