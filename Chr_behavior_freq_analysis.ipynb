# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('freq.xlsx')
df
# Out:
#          Multiple congress attemps  lingering chr at poles  bad met  \
# DMSO                           0.1                    0.10    0.200
# Prodrug                        0.0                    0.22    0.000
# C4                             0.0                    0.20    0.100
# B4                             0.0                    0.28    0.056
#
#          not all chr congress  lagging chr  straggling chr in ana  \
# DMSO                     0.00        0.000                   0.00
# Prodrug                  0.11        0.000                   0.33
# C4                       0.00        0.200                   0.00
# B4                       0.17        0.056                   0.11
#
#          total align defect  total ana defects
# DMSO                   0.20               0.00
# Prodrug                0.33               0.33
# C4                     0.10               0.20
# B4                     0.50               0.11

# %%
fig = plt.figure(figsize=(10, 4))
plt.title('Frequency Analysis')
sns.heatmap(df, cmap ='coolwarm')

# %%
fig = plt.figure(figsize=(10, 4))
plt.title('Frequency Analysis')
sns.heatmap(df, cmap ='coolwarm', annot= df)

# %%
fig.savefig('freq.png')
